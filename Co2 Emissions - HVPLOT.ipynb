# %%
pip install panel hvplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: panel in /usr/local/lib/python3.7/dist-packages (0.12.1)
# Collecting hvplot
#   Downloading hvplot-0.8.0-py2.py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 8.3 MB/s
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.7/dist-packages (from panel) (4.64.0)
# Requirement already satisfied: bokeh<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from panel) (2.3.3)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.7/dist-packages (from panel) (0.4.8)
# Requirement already satisfied: param>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from panel) (1.12.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from panel) (2.2.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from panel) (5.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from panel) (2.23.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from panel) (3.3.7)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (3.13)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (1.21.6)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (21.3)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (5.1.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (4.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.4.0,>=2.3.0->panel) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh<2.4.0,>=2.3.0->panel) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh<2.4.0,>=2.3.0->panel) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh<2.4.0,>=2.3.0->panel) (1.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from hvplot) (1.3.5)
# Requirement already satisfied: holoviews>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from hvplot) (1.14.9)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.7/dist-packages (from hvplot) (3.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->hvplot) (2022.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown->panel) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown->panel) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->panel) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->panel) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->panel) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->panel) (1.24.3)
# Installing collected packages: hvplot
# Successfully installed hvplot-0.8.0

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
df
# Out:
#       iso_code      country  year     co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949   0.015           0.002        NaN
# 1          AFG  Afghanistan  1950   0.084           0.011        NaN
# 2          AFG  Afghanistan  1951   0.092           0.012        NaN
# 3          AFG  Afghanistan  1952   0.092           0.012        NaN
# 4          AFG  Afghanistan  1953   0.106           0.013        NaN
# ...        ...          ...   ...     ...             ...        ...
# 25984      ZWE     Zimbabwe  2016  10.738           0.765      1.415
# 25985      ZWE     Zimbabwe  2017   9.582           0.673      1.666
# 25986      ZWE     Zimbabwe  2018  11.854           0.821      1.308
# 25987      ZWE     Zimbabwe  2019  10.949           0.748      1.473
# 25988      ZWE     Zimbabwe  2020  10.531           0.709        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0             NaN                    NaN     0.015                0.002  ...
# 1             NaN                    NaN     0.021                0.003  ...
# 2             NaN                    NaN     0.026                0.003  ...
# 3             NaN                    NaN     0.032                0.004  ...
# 4             NaN                    NaN     0.038                0.005  ...
# ...           ...                    ...       ...                  ...  ...
# 25984       0.639                  0.046     6.959                0.496  ...
# 25985       0.678                  0.048     5.665                0.398  ...
# 25986       0.697                  0.048     7.101                0.492  ...
# 25987       0.697                  0.048     6.020                0.411  ...
# 25988       0.697                  0.047     6.257                0.421  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 0                                NaN      NaN                 NaN
# 1                                NaN      NaN                 NaN
# 2                                NaN      NaN                 NaN
# 3                                NaN      NaN                 NaN
# 4                                NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 25984                          2.076    11.50               0.820
# 25985                          2.023    11.62               0.816
# 25986                          2.173    11.96               0.828
# 25987                            NaN      NaN                 NaN
# 25988                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 0                NaN                       NaN   7624058.0           NaN
# 1                NaN                       NaN   7752117.0  9.421400e+09
# 2                NaN                       NaN   7840151.0  9.692280e+09
# 3                NaN                       NaN   7935996.0  1.001733e+10
# 4                NaN                       NaN   8039684.0  1.063052e+10
# ...              ...                       ...         ...           ...
# 25984           6.21                     0.443  14030338.0  2.096179e+10
# 25985           6.35                     0.446  14236599.0  2.194784e+10
# 25986           6.59                     0.456  14438812.0  2.271535e+10
# 25987            NaN                       NaN  14645473.0           NaN
# 25988            NaN                       NaN  14862927.0           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                             NaN                NaN             NaN
# 1                             NaN                NaN             NaN
# 2                             NaN                NaN             NaN
# 3                             NaN                NaN             NaN
# 4                             NaN                NaN             NaN
# ...                           ...                ...             ...
# 25984                      46.666           3326.073           2.226
# 25985                      45.936           3226.617           2.093
# 25986                      47.502           3289.887           2.091
# 25987                      49.427           3374.877             NaN
# 25988                         NaN                NaN             NaN
#
# [25989 rows x 60 columns]

# %%
df[df['country'] == 'North America']
# Out:
#       iso_code        country  year       co2  co2_per_capita  trade_co2  \
# 16785      NaN  North America  1785     0.004             NaN        NaN
# 16786      NaN  North America  1786     0.004             NaN        NaN
# 16787      NaN  North America  1787     0.004             NaN        NaN
# 16788      NaN  North America  1788     0.004             NaN        NaN
# 16789      NaN  North America  1789     0.004             NaN        NaN
# ...        ...            ...   ...       ...             ...        ...
# 17016      NaN  North America  2016  6471.360          11.353    309.904
# 17017      NaN  North America  2017  6412.982          11.155    335.009
# 17018      NaN  North America  2018  6588.630          11.366    345.915
# 17019      NaN  North America  2019  6460.726          11.056    354.353
# 17020      NaN  North America  2020  5775.159           9.805        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 16785         NaN                    NaN     0.004                  NaN  ...
# 16786         NaN                    NaN     0.004                  NaN  ...
# 16787         NaN                    NaN     0.004                  NaN  ...
# 16788         NaN                    NaN     0.004                  NaN  ...
# 16789         NaN                    NaN     0.004                  NaN  ...
# ...           ...                    ...       ...                  ...  ...
# 17016      70.858                  0.124  1509.631                2.648  ...
# 17017      72.914                  0.127  1467.602                2.553  ...
# 17018      74.787                  0.129  1398.979                2.413  ...
# 17019      76.925                  0.132  1214.329                2.078  ...
# 17020      76.870                  0.130   965.430                1.639  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 16785                            NaN      NaN                 NaN
# 16786                            NaN      NaN                 NaN
# 16787                            NaN      NaN                 NaN
# 16788                            NaN      NaN                 NaN
# 16789                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 17016                            NaN      NaN                 NaN
# 17017                            NaN      NaN                 NaN
# 17018                            NaN      NaN                 NaN
# 17019                            NaN      NaN                 NaN
# 17020                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita   population  gdp  \
# 16785            NaN                       NaN          NaN  NaN
# 16786            NaN                       NaN          NaN  NaN
# 16787            NaN                       NaN          NaN  NaN
# 16788            NaN                       NaN          NaN  NaN
# 16789            NaN                       NaN          NaN  NaN
# ...              ...                       ...          ...  ...
# 17016            NaN                       NaN  573814461.0  NaN
# 17017            NaN                       NaN  578582963.0  NaN
# 17018            NaN                       NaN  582921781.0  NaN
# 17019            NaN                       NaN  587512621.0  NaN
# 17020            NaN                       NaN  592062319.0  NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 16785                         NaN                NaN             NaN
# 16786                         NaN                NaN             NaN
# 16787                         NaN                NaN             NaN
# 16788                         NaN                NaN             NaN
# 16789                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 17016                         NaN                NaN             NaN
# 17017                         NaN                NaN             NaN
# 17018                         NaN                NaN             NaN
# 17019                         NaN                NaN             NaN
# 17020                         NaN                NaN             NaN
#
# [236 rows x 60 columns]

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='1005'>
#
#
#
#
#
#   <div class="bk-root" id="e5f420ed-7cd2-4c58-9596-17a4ad8f41e5" data-root-id="1005"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"2c83590e-f00d-4ab5-95ae-7b84193367da":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,5,5,5],"name":"DataFrame04011","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1750&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1751&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1751&lt;/td&gt;\n      &lt;td&gt;9.351&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1752&lt;/td&gt;\n      &lt;td&gt;9.354&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;5&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1752&lt;/td&gt;\n      &lt;td&gt;9.354&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;6&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1753&lt;/td&gt;\n      &lt;td&gt;9.354&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;7&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1753&lt;/td&gt;\n      &lt;td&gt;9.354&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;8&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1754&lt;/td&gt;\n      &lt;td&gt;9.358&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;9&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1754&lt;/td&gt;\n      &lt;td&gt;9.358&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;10&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1755&lt;/td&gt;\n      &lt;td&gt;9.362&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;11&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1755&lt;/td&gt;\n      &lt;td&gt;9.362&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;12&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1756&lt;/td&gt;\n      &lt;td&gt;10.006&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;13&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1756&lt;/td&gt;\n      &lt;td&gt;10.006&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;14&lt;/th&gt;\n      &lt;td&gt;Europe&lt;/td&gt;\n      &lt;td&gt;1757&lt;/td&gt;\n      &lt;td&gt;10.010&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;15&lt;/th&gt;\n      &lt;td&gt;World&lt;/td&gt;\n      &lt;td&gt;1757&lt;/td&gt;\n      &lt;td&gt;10.010&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;16&lt;/th&gt;\n      &lt;t ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent")
co2_plot
# Out:
# <div id='1015'>
#
#
#
#
#
#   <div class="bk-root" id="cf6b4477-9281-4560-8a4f-31543897d58d" data-root-id="1015"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"b5ff766d-683d-42b1-aec9-3298ca338ee1":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"source":{"id":"1131"}},"id":"1138","type":"CDSView"},{"attributes":{},"id":"1103","type":"UnionRenderers"},{"attributes":{},"id":"1086","type":"Selection"},{"attributes":{"client_comm_id":"a683db7b0672478b84aa1b6e60b2b297","comm_id":"ffd719a566e44025877a53f999fd1e93","plot_id":"1015"},"id":"1349","type":"panel.models.comm_manager.CommManager"},{"attributes":{"label":{"value":"World"},"renderers":[{"id":"1137"}]},"id":"1155","type":"LegendItem"},{"attributes":{"data_source":{"id":"1085"},"glyph":{"id":"1088"},"hover_glyph":null,"muted_glyph":{"id":"1090"},"nonselection_glyph":{"id":"1089"},"selection_glyph":{"id":"1106"},"view":{"id":"1092"}},"id":"1091","type":"GlyphRenderer"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year slider","value":1850},"id":"1019","type":"Slider"},{"attributes":{"line_alpha":0.1,"line_color":"#fc4f30","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1089","type":"Line"},{"attributes":{"line_color":"#6d904f","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1156","type":"Line"},{"attributes":{"data":{"co2":{"__ndarray__":"/Knx0k1iYD/6fmq8dJNoP/yp8dJNYmA//Knx0k1iYD8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAALgehetRuI4/","dtype":"float64","order":"little","shape":[21]},"country":["Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia"],"year":[1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,1842,1843,1844,1845,1846,1847,1848,1849,1850]},"selected":{"id":"1065"},"selection_policy":{"id":"1080"}},"id":"1064","type":"ColumnDataSource"},{"attributes":{"source":{"id":"1085"}},"id":"1092","type":"CDSView"},{"attributes":{"source":{"id":"1064"}},"id":"1071","type":"CDSView"},{"attributes":{"line_alpha":0.2,"line_color":"#6d904f","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1136","type":"Line"},{"attributes":{},"id":"1033","type":"LinearScale"},{"attributes":{"line_color":"#fc4f30","line_width":2,"x":{"field":"year"},"y":{"field":"co2"}},"id":"1088","type":"Line"},{"attributes":{"data":{"co2":{"__ndarray__":"...","dtype":"float64","order":"little","shape":[101]},"country":["Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Eu ...

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='1430'>
#
#
#
#
#
#   <div class="bk-root" id="94456be4-c69a-4aff-8c55-cdcd5c4d3e47" data-root-id="1430"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"925a0c6b-ec05-409d-9012-e6351fd6f037":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"editor":{"id":"1442"},"field":"index","formatter":{"id":"1440"},"title":"index","width":0},"id":"1443","type":"TableColumn"},{"attributes":{"children":[{"id":"1432"},{"id":"1437"}],"margin":[0,0,0,0],"name":"Column05575"},"id":"1431","type":"Column"},{"attributes":{"editor":{"id":"1457"},"field":"co2","formatter":{"id":"1456"},"title":"co2","width":0},"id":"1458","type":"TableColumn"},{"attributes":{"children":[{"id":"1433"},{"id":"1436"}],"margin":[0,0,0,0],"name":"Row05574"},"id":"1432","type":"Row"},{"attributes":{},"id":"1451","type":"NumberFormatter"},{"attributes":{},"id":"1440","type":"NumberFormatter"},{"attributes":{"editor":{"id":"1447"},"field":"country","formatter":{"id":"1446"},"title":"country","width":0},"id":"1448","type":"TableColumn"},{"attributes":{"editor":{"id":"1452"},"field":"year","formatter":{"id":"1451"},"title":"year","width":0},"id":"1453","type":"TableColumn"},{"attributes":{"children":[{"id":"1434"},{"id":"1435"}],"margin":[0,0,0,0],"name":"Column05492"},"id":"1433","type":"Column"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year slider","value":1850},"id":"1434","type":"Slider"},{"attributes":{"columns":[{"id":"1443"},{"id":"1448"},{"id":"1453"},{"id":"1458"}],"configuration":{"columns":[{"field":"index"},{"field":"country"},{"field":"year"},{"field":"co2"}],"dataTree":false,"selectable":true},"height":330,"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":29,"name":"","page":1,"page_size":10,"pagination":"remote","selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"1438"}},"id":"1461","type":"panel.models.tabulator.DataTabulator"},{"attributes":{},"id":"1452","type":"IntEditor"},{"attributes":{},"id":"1463","type":"UnionRenderers"},{"attributes":{},"id":"1442","type":"CellEditor"},{"attributes":{"indices":[]},"id":"1439","type":"Selection"},{"attributes":{},"id":"1447","type":"StringEditor"},{"attributes":{},"id":"1457","type":"NumberEditor"},{"attributes":{"children":[{"id":"1431"}],"margin":[0,0,0,0],"name":"Row05576"},"id":"1430","type":"Row"},{"attributes":{},"id":"1446","type":"StringFormatter"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer05573","sizing_mode":"stretch_width"},"id":"1436","type":"Spacer"},{"attributes":{"active":0,"button_type":"success","labels":["co2","co2_per_capita"],"margin":[5,10,5,10]},"id":"1435","type":"RadioButtonGroup"},{"attributes":{"client_comm_id":"b11c13409773478485d9298b21634842","comm_id":"f03ec0f36cc4439fa9bbd0bc2849c47e","plot_id":"1430"},"id":"1469","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1461"}],"margin":[0,0,0,0],"name":"Row05497"},"id":"1437","type":"Row"},{"attributes":{"format":"0,0.0[00000]"},"id":"1456","type":"NumberFormatter"},{"attributes":{"data":{"co2":{"__ndarray__":"wcqhRbazIkDByqFFtrMiQMHKoUW2syJAwcqhRbazIkBoke18P7UiQGiR7Xw/tSJAaJHtfD+1IkBoke18P7UiQJ7vp8ZLtyJAnu+nxku3IkA=","dtype":"float64","order":"little","shape":[10]},"country":["Europe","World","Europe","World","Europe","World","World","Europe","World","Eu ...
#     var render_items = [{"docid":"925a0c6b-ec05-409d-9012-e6351fd6f037","root_ids":["1430"],"roots":{"1430":"94456be4-c69a-4aff-8c55-cdcd5c4d3e47"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='1480'>
#
#
#
#
#
#   <div class="bk-root" id="0430ba02-6701-4119-aa91-8135f45b8479" data-root-id="1480"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"378baf68-9b47-4baf-bb41-934a8caa29a8":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,5,5,5],"name":"HSpacer08034","sizing_mode":"stretch_width"},"id":"1485","type":"Spacer"},{"attributes":{"client_comm_id":"c89b9bf5385f484aa512b489734f7609","comm_id":"7497780f54804504af6c3d6a11c46b11","plot_id":"1480"},"id":"1488","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1482"},{"id":"1486"}],"margin":[0,0,0,0],"name":"Column08036"},"id":"1481","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame08032","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;country&lt;/th&gt;\n      &lt;th&gt;year&lt;/th&gt;\n      &lt;th&gt;gdp_per_capita&lt;/th&gt;\n      &lt;th&gt;co2&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Armenia&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Latvia&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.001&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;Lithuania&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.001&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;Lower-middle-income countries&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.026&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;Moldova&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.001&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;5&lt;/th&gt;\n      &lt;td&gt;Netherlands&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;3779.332983&lt;/td&gt;\n      &lt;td&gt;3.136&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;6&lt;/th&gt;\n      &lt;td&gt;North America (excl. USA)&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.059&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;7&lt;/th&gt;\n      &lt;td&gt;Norway&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;1620.608579&lt;/td&gt;\n      &lt;td&gt;0.139&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;8&lt;/th&gt;\n      &lt;td&gt;Kyrgyzstan&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;0.000000&lt;/td&gt;\n      &lt;td&gt;0.001&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;9&lt;/th&gt;\n      &lt;td&gt;Poland&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;981.556639&lt;/td&gt;\n      &lt;td&gt;3.202&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;10&lt;/th&gt;\n      &lt;td&gt;Spain&lt;/td&gt;\n      &lt;td&gt;1850&lt;/td&gt;\n      &lt;td&gt;1707.725792 ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='1489'>
#
#
#
#
#
#   <div class="bk-root" id="b370e2a7-e84c-416c-8815-630556b3c623" data-root-id="1489"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"1929db0d-da32-45ee-a6c7-558eba5ad565":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"data_source":{"id":"1789"},"glyph":{"id":"1792"},"hover_glyph":null,"muted_glyph":{"id":"1794"},"nonselection_glyph":{"id":"1793"},"selection_glyph":{"id":"1797"},"view":{"id":"1796"}},"id":"1795","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"1559"}},"id":"1557","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#30a2da"},"line_alpha":{"value":0.7},"line_color":{"value":"#30a2da"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"1793","type":"Scatter"},{"attributes":{"source":{"id":"1789"}},"id":"1796","type":"CDSView"},{"attributes":{"data":{"co2":{"__ndarray__":"/Knx0k1iYD8=","dtype":"float64","order":"little","shape":[1]},"country":["Azerbaijan"],"gdp_per_capita":{"__ndarray__":"AAAAAAAAAAA=","dtype":"float64","order":"little","shape":[1]}},"selected":{"id":"1601"},"selection_policy":{"id":"1938"}},"id":"1600","type":"ColumnDataSource"},{"attributes":{"source":{"id":"1573"}},"id":"1580","type":"CDSView"},{"attributes":{"data":{"co2":{"__ndarray__":"/Knx0k1iUD8=","dtype":"float64","order":"little","shape":[1]},"country":["Latvia"],"gdp_per_capita":{"__ndarray__":"AAAAAAAAAAA=","dtype":"float64","order":"little","shape":[1]}},"selected":{"id":"1763"},"selection_policy":{"id":"1974"}},"id":"1762","type":"ColumnDataSource"},{"attributes":{},"id":"1601","type":"Selection"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.7},"line_color":{"value":"#1f77b4"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"1757","type":"Scatter"},{"attributes":{},"id":"1700","type":"Selection"},{"attributes":{},"id":"1558","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#9467bd"},"line_alpha":{"value":0.2},"line_color":{"value":"#9467bd"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"1740","type":"Scatter"},{"attributes":{"angle":{"value":0.0},"fill_alpha":{"value":0.7},"fill_color":{"value":"#e5ae38"},"hatch_alpha":{"value":1.0},"hatch_color":{"value":"black"},"hatch_scale":{"value":12.0},"hatch_weight":{"value":1.0},"line_alpha":{"value":0.7},"line_cap":{"value":"butt"},"line_color":{"value":"#e5ae38"},"line_dash":{"value":[]},"line_dash_offset":{"value":0},"line_join":{"value":"bevel"},"line_width":{"value":1},"marker":{"value":"circle"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"1815","type":"Scatter"},{"attributes":{"end":216.46460000000002,"reset_end":216.46460000000002,"reset_start":-19.678600000000003,"start":-19.678600000000003,"tags":[[["co2","co2",null]]]},"id":"1497","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#e377c2"},"line_alpha":{"value":0.7},"line_color":{"value":"#e377c2"},"size":{"value":8.94427190999916},"x":{"field":"gdp_per_capita"},"y":{"field":"co2"}},"id":"1765","type":"Scatter"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#fc4f30"},"line_alpha":{"v ...

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='3387'>
#
#
#
#
#
#   <div class="bk-root" id="3a2d3279-fda8-40bc-9d0c-da597e912af8" data-root-id="3387"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"9868b959-af3f-4a86-811d-00d54c7654f1":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"data_source":{"id":"3427"},"glyph":{"id":"3430"},"hover_glyph":null,"muted_glyph":{"id":"3432"},"nonselection_glyph":{"id":"3431"},"selection_glyph":{"id":"3435"},"view":{"id":"3434"}},"id":"3433","type":"GlyphRenderer"},{"attributes":{"axis":{"id":"3410"},"dimension":1,"grid_line_color":null,"ticker":null},"id":"3413","type":"Grid"},{"attributes":{"fill_color":{"value":"#30a2da"},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"3430","type":"VBar"},{"attributes":{},"id":"3414","type":"SaveTool"},{"attributes":{},"id":"3418","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#30a2da"},"line_alpha":{"value":0.1},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"3431","type":"VBar"},{"attributes":{"axis":{"id":"3407"},"grid_line_color":null,"ticker":null},"id":"3409","type":"Grid"},{"attributes":{"children":[{"id":"3389"},{"id":"3394"}],"margin":[0,0,0,0],"name":"Column17997"},"id":"3388","type":"Column"},{"attributes":{},"id":"3439","type":"AllLabels"},{"attributes":{"text":"CO2 source by continent","text_color":"black","text_font_size":"12pt"},"id":"3399","type":"Title"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#30a2da"},"line_alpha":{"value":0.2},"top":{"field":"coal_co2"},"width":{"value":0.8},"x":{"field":"country"}},"id":"3432","type":"VBar"},{"attributes":{"overlay":{"id":"3419"}},"id":"3417","type":"BoxZoomTool"},{"attributes":{"end":2020,"margin":[5,10,5,10],"start":1750,"step":5,"title":"Year slider","value":1850},"id":"3391","type":"Slider"},{"attributes":{"source":{"id":"3427"}},"id":"3434","type":"CDSView"},{"attributes":{"children":[{"id":"3398"}],"margin":[0,0,0,0],"name":"Row17784"},"id":"3394","type":"Row"},{"attributes":{},"id":"3415","type":"PanTool"},{"attributes":{"active":0,"button_type":"success","labels":["coal_co2","oil_co2","gas_co2"],"margin":[5,10,5,10]},"id":"3392","type":"RadioButtonGroup"},{"attributes":{"bottom_units":"screen","fill_alpha":0.5,"fill_color":"lightgrey","left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"3419","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"3390"},{"id":"3393"}],"margin":[0,0,0,0],"name":"Row17996"},"id":"3389","type":"Row"},{"attributes":{},"id":"3416","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"3407"}],"center":[{"id":"3409"},{"id":"3413"}],"height":300,"left":[{"id":"3410"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"3433"}],"sizing_mode":"fixed","title":{"id":"3399"},"toolbar":{"id":"3420"},"width":700,"x_range":{"id":"3395"},"x_scale":{"id":"3403"},"y_range":{"id":"3396"},"y_scale":{"id":"3405"}},"id":"3398","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"3438","type":"CategoricalTickFormatter"},{"attributes":{},"id":"3411","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value": ...
#     var render_items = [{"docid":"9868b959-af3f-4a86-811d-00d54c7654f1","root_ids":["3387"],"roots":{"3387":"3a2d3279-fda8-40bc-9d0c-da597e912af8"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#Creating the dashboard

#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG("https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pngall.com%2Fclimate-change-png%2Fdownload%2F15556&psig=AOvVaw30Jr9UJ4La9J_JMt98GjZV&ust=1653131628071000&source=images&cd=vfe&ved=0CAwQjRxqFwoTCKCn-q357fcCFQAAAAAdAAAAABAO", sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# Launching server at http://localhost:43463
